# %% [markdown]
# # Section 1: Using Cloudera AI and Jupyter Notebooks
#
# Step 1  - How to Login
# Step 2 - Navigate to Cloudera Workbench
# Step 3 - Open Cloudera Workbench
# Step 4 - Open your Project
# Step 5 - Commence Juypter Session
# Step 6 - Click on Labs on left hand side
